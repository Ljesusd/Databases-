# %% [markdown]
# ### divide_dataframe

# %%
from mh_toolbox.utils.common_utils import divide_dataframe
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3, 4, 5, 6, 7, 8, 9]})
indexes = [0, 1, 6, 7]
dfs = divide_dataframe(df, indexes)

# %%
[print('here:', dfs[i]) for i in range(len(dfs))]
