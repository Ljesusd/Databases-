# %%
from mh_toolbox.characterization.statistical.statistical_features import StatisticalAnalysisStrategy
import mh_toolbox.base.eurobench_element as eb
import numpy as np

filename = '/Users/jorge/Documents/Coding/Projects/personal-projects/motion-hub-toolbox/mh_toolbox/characterization/subject_3_cond_1_run_6_jointAngles.csv'
events = None
info = None

element = eb.EurobenchElement(key_id='acceleration')
element.initialize(data_filename=filename, events_filename=events, info_filename=info)

statistical_analysis = StatisticalAnalysisStrategy()
statistical_analysis.initialize(element)

_ = statistical_analysis.compute_statistics(cols_to_process=None)
# Out:
# 2024-07-15 22:11:45.608 | DEBUG    | mh_toolbox.base.eurobench_element:add_data:362 - Adding data object.
# 2024-07-15 22:11:45.609 | INFO     | mh_toolbox.base.base_eurobench:load_base_from_filename:34 - Loading file /Users/jorge/Documents/Coding/Projects/personal-projects/motion-hub-toolbox/mh_toolbox/characterization/subject_3_cond_1_run_6_jointAngles.csv
# 2024-07-15 22:11:45.613 | WARNING  | mh_toolbox.base.base_eurobench:load_time:314 - There is already a column named 'time' in the data. Using it as a time_key.
