# %%
from mh_toolbox.characterization.complexity.complexity_features import ComplexityAnalysisStrategy
import mh_toolbox.base.eurobench_element as eb

filename = '/Users/jorge/Documents/Coding/Projects/personal-projects/motion-hub-toolbox/mh_toolbox/characterization/subject_3_cond_1_run_6_jointAngles.csv'
events = None
info = None

element = eb.EurobenchElement(key_id='acceleration')
element.initialize(data_filename=filename, events_filename=events, info_filename=info)

complexity_analysis = ComplexityAnalysisStrategy()
complexity_analysis.initialize(element)

_ = complexity_analysis.compute_statistics(cols_to_process=None)
# Out:
# 2024-07-15 21:41:04.942 | DEBUG    | mh_toolbox.base.eurobench_element:add_data:362 - Adding data object.
# 2024-07-15 21:41:04.942 | INFO     | mh_toolbox.base.base_eurobench:load_base_from_filename:34 - Loading file /Users/jorge/Documents/Coding/Projects/personal-projects/motion-hub-toolbox/mh_toolbox/characterization/subject_3_cond_1_run_6_jointAngles.csv
# 2024-07-15 21:41:04.948 | WARNING  | mh_toolbox.base.base_eurobench:load_time:314 - There is already a column named 'time' in the data. Using it as a time_key.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 element = eb.EurobenchElement(key_id='acceleration')
#       9 element.initialize(data_filename=filename, events_filename=events, info_filename=info)
# ---> 11 complexity_analysis = ComplexityAnalysisStrategy()
#      12 complexity_analysis.initialize(element)
#      14 _ = complexity_analysis.compute_statistics(cols_to_process=None)
#
# TypeError: Can't instantiate abstract class ComplexityAnalysisStrategy with abstract method process_element
