# %%
import sys
import pandas as pd
import numpy as np

sys.path.append(
    '/Users/jorge/Documents/Coding/Projects/nrg-standardization/photogrammetry/preprocess_data_vicon/vicon_utils')

import importlib
import utils

importlib.reload(utils)

# %%
sys.path.append(
    '/Users/jorge/Documents/Coding/SmallProjects/2023/KineticToolbox/kineticstoolkit/')
import kineticstoolkit as ktk

importlib.reload(ktk)

# %% [markdown]
# # Read C3D file

# %%
filename= '/Users/jorge/BasesDatos/ExemplaryData/AI4HA/PILOT_TRIALS/PREPROCESSED_RAW_DATA/SUBJECT_10/SESSION_01/GROSS_MOTOR_BIOMETRY/VICON/SUBJECT_10/SESSION_01/subject_10_cond_13_run_01.c3d'


data = ktk.read_c3d(filename, include_metadata=True)

# %%
# %matplotlib osx

ktk.Player(data["Points"], up="z")
