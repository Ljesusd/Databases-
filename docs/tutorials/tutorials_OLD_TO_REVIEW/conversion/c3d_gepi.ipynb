# %%
import pathlib
import importlib
import mh_toolbox.conversion.c3d.c3d_eurobench as eur
importlib.reload(eur)

gepi_path = pathlib.Path('../../data/c3d/GePi_S01')
pattern = r"subject_(?P<subject>\w+)_cond_(?P<condition>\w+)_run_(?P<run>\w+)"

c3d_eurobench = eur.C3DEurobench()
list_c3d_files = c3d_eurobench.convert_dir_c3d_to_eurobench(dir_in=gepi_path, 
                                                            dict_keep_drop_cols_data={'Trajectories':['!*']},
                                                            dir_out='../../data/c3d/GePi_conv_S01', 
                                                            b_save_info=True,
                                                            b_save_data=True,
                                                            b_save_events=True,
                                                            pattern_subject_condition_run=pattern)
list_c3d_files
# Out:
# 2024-04-05 12:13:07.967 | INFO     | mh_toolbox.conversion.c3d.c3d_eurobench:convert_dir_c3d_to_eurobench:239 -  File: ../../data/c3d/GePi_S01/subject_01_cond_09_run_04.c3d
# 2024-04-05 12:13:08.005 | INFO     | mh_toolbox.classes.eurobench_data:curate_and_save_dataframes:514 - Processing Trajectories...
# 2024-04-05 12:13:08.007 | INFO     | mh_toolbox.classes.eurobench_data:curate_and_save_dataframes:526 - Saving at ../../data/c3d/GePi_conv_S01/subject_01_condition_09_run_04_Trajectories.csv
# 2024-04-05 12:13:08.101 | WARNING  | mh_toolbox.classes.eurobench_data:curate_and_save_dataframes:500 - Empty dataframe for subject_01_condition_09_run_04
# 2024-04-05 12:13:08.102 | INFO     | mh_toolbox.conversion.c3d.c3d_eurobench:convert_dir_c3d_to_eurobench:239 -  File: ../../data/c3d/GePi_S01/subject_01_cond_01_run_03.c3d
# 2024-04-05 12:13:08.252 | INFO     | mh_toolbox.classes.eurobench_data:curate_and_save_dataframes:514 - Processing Trajectories...
# ...

# %%
list_c3d_files[0].data
# Out:
#        time      lfhd_x      lfhd_y       lfhd_z      rfhd_x      rfhd_y  \
# 0      0.00  264.609253  513.201843  1669.318359  256.543335  376.891357
# 1      0.01  265.041809  513.207153  1669.215576  256.925629  376.918701
# 2      0.02  265.453339  513.211304  1669.105225  257.313599  376.922333
# 3      0.03  265.890442  513.204529  1668.990479  257.650085  376.925598
# 4      0.04  266.303955  513.185059  1668.888428  257.995544  376.907379
# ...     ...         ...         ...          ...         ...         ...
# 2633  26.33  359.225494  532.976562  1657.639648  357.422485  396.264557
# 2634  26.34  358.468353  532.965820  1657.950562  356.668915  396.286926
# 2635  26.35  357.695099  533.002686  1658.192871  355.978485  396.348846
# 2636  26.36  356.975494  532.994934  1658.444946  355.262848  396.376678
# 2637  26.37  356.302185  532.921997  1658.712402  354.518097  396.314911
#
#            rfhd_z      lbhd_x      lbhd_y       lbhd_z  ...  r_footc1_z  \
# ...
