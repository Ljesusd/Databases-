# %% [markdown]
# ## Load data

# %% [markdown]
# ### load_csv_or_yaml_file
# The function `load_file` is used to load a file. It takes:
# - `file_path`: Path to the file
# - `file_type`: Type of the file. It can be `csv` or `yaml`

# %%
from mh_toolbox.utils.common_utils import load_csv_or_yaml_file
file_path = '../../data/eurobench_data/data_simple/subject_1_cond_1_run_1_data.csv'
file_type = "csv"
result = load_csv_or_yaml_file(file_path, file_type)
result.head()

# %% [markdown]
# ### yaml_utils

# %%
import mh_toolbox.utils.yaml_utils as conv

# %%
events_dict = {'l_heel_strike': [6.27, 7.48, 8.86],
               'l_toe_off': [7.03, 8.42],
               'r_heel_strike': [5.62, 6.85, 8.15],
               'r_toe_off': [6.48, 7.77]}
starting_string = 'l_'

# %%
conv.flat_yaml_dictionary(events_dict, starting_string)
