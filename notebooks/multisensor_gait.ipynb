# %% [markdown]
# ## Runner

# %%
# !python src/datasets/multisensor/process_multisensor_markers.py --all --overwrite --angle-mode 3d --hip-sagittal --ankle-zero

# %%
# !python src/datasets/multisensor/plot_population_profiles_flexion_all_trials.py

# %%
# !python src/datasets/multisensor/select_subjects_closest_literature.py
